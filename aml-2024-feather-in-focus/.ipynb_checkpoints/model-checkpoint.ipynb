# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import cv2

# %%
# load class_names
labels = np.load("class_names.npy", allow_pickle=True).item()

# load attributes
attributes = np.load("attributes.npy")
print(attributes.shape)
attributes_dict = {i + 1: row for i, row in enumerate(attributes)}
# load training data
train_df = pd.read_csv("train_images.csv")
# add attributes to data
train_df["attributes"] = train_df["label"].map(attributes_dict)
train_df.head()
# Out:
# (200, 312)
#             image_path  label  \
# 0  /train_images/1.jpg      1
# 1  /train_images/2.jpg      1
# 2  /train_images/3.jpg      1
# 3  /train_images/4.jpg      1
# 4  /train_images/5.jpg      1
#
#                                           attributes
# 0  [0.010638400403539122, 0.010638400403539122, 0...
# 1  [0.010638400403539122, 0.010638400403539122, 0...
# 2  [0.010638400403539122, 0.010638400403539122, 0...
# 3  [0.010638400403539122, 0.010638400403539122, 0...
# 4  [0.010638400403539122, 0.010638400403539122, 0...

# %%
# Initialize empty lists for images (X) and labels (y)
X = []
y = []

# Iterate over rows in the DataFrame
for _, row in train_df.iterrows():
    # Read the image
    im_path = row['image_path']
    image = cv2.imread(f'train_images{im_path}')
    
    # Resize the image to 400x400
    image_resized = cv2.resize(image, (400, 400))
    
    # Append to the list of images and labels
    X.append(image_resized)

# Convert lists to numpy arrays (optional)
X = np.array(X)
y = train_df['label']

# %%
# Convert y to categorical
y_c = to_categorical(y.values-1)
X_train, X_test, y_train, y_test = train_test_split(X, y_c, test_size=0.2, random_state=0)
# use one-hot encoding for labels
print(y_train.shape)
# Out:
# (3140, 200)

# %%
# Initialize the EfficientNetV2 model with default settings
base_model = EfficientNetV2S(
    include_top=False,       # Exclude the classification head
    weights="imagenet",      # Use pre-trained weights from ImageNet
    input_shape=(400, 400, 3)  # Input image size (H, W, C)
)

# View the model architecture
base_model.summary()
# Out:
# Model: "efficientnetv2-s"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 400, 400, 3)]        0         []
#
#  rescaling_3 (Rescaling)     (None, 400, 400, 3)          0         ['input_4[0][0]']
#
#  stem_conv (Conv2D)          (None, 200, 200, 24)         648       ['rescaling_3[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 200, 200, 24)         96        ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 200, 200, 24)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 200, 200, 24)         5184      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 200, 200, 24)         96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 200, 200, 24)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1a_add (Add)           (None, 200, 200, 24)         0         ['block1a_project_activation[0
#                                                                     ][0]',
#                                                                      'stem_activation[0][0]']
#
#  block1b_project_conv (Conv  (None, 200, 200, 24)         5184      ['block1a_add[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 200, 200, 24)         96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 200, 200, 24)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 200, 200, 24)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 200, 200, 24)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 100, 100, 96)         20736     ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 100, 100, 96)         384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 100, 100, 96)         0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 100, 100, 48)         4608      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 100, 100, 48)         192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 100, 100, 192)        82944     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 100, 100, 192)        768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 100, 100, 192)        0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 100, 100, 48)         9216      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 100, 100, 48)         192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 100, 100, 48)         0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 100, 100, 48)         0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 100, 100, 192)        82944     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 100, 100, 192)        768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 100, 100, 192)        0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 100, 100, 48)         9216      ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 100, 100, 48)         192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 100, 100, 48)         0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 100, 100, 48)         0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 100, 100, 192)        82944     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 100, 100, 192)        768       ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 100, 100, 192)        0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_project_conv (Conv  (None, 100, 100, 48)         9216      ['block2d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2d_project_bn (BatchN  (None, 100, 100, 48)         192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 100, 100, 48)         0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 100, 100, 48)         0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 50, 50, 192)          82944     ['block2d_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 50, 50, 192)          768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 50, 50, 192)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 50, 50, 64)           12288     ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 50, 50, 64)           256       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 50, 50, 256)          147456    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 50, 50, 256)          1024      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 50, 50, 256)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 50, 50, 64)           16384     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 50, 50, 64)           256       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 50, 50, 64)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 50, 50, 64)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 50, 50, 256)          147456    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 50, 50, 256)          1024      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 50, 50, 256)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 50, 50, 64)           16384     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 50, 50, 64)           256       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 50, 50, 64)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 50, 50, 64)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 50, 50, 256)          147456    ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 50, 50, 256)          1024      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 50, 50, 256)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_project_conv (Conv  (None, 50, 50, 64)           16384     ['block3d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3d_project_bn (BatchN  (None, 50, 50, 64)           256       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (Dropout)      (None, 50, 50, 64)           0         ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)           (None, 50, 50, 64)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 50, 50, 256)          16384     ['block3d_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 50, 50, 256)          1024      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 50, 50, 256)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 25, 25, 256)          2304      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 25, 25, 256)          1024      ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 25, 25, 256)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 256)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 256)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 16)             4112      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 256)            4352      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 25, 25, 256)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 25, 25, 128)          32768     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 25, 25, 128)          512       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 25, 25, 512)          65536     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 25, 25, 512)          2048      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 25, 25, 512)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 25, 25, 512)          4608      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 25, 25, 512)          2048      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 25, 25, 512)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 512)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 25, 25, 512)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 25, 25, 128)          65536     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 25, 25, 128)          512       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 25, 25, 128)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 25, 25, 128)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 25, 25, 512)          65536     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 25, 25, 512)          2048      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 25, 25, 512)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 25, 25, 512)          4608      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 25, 25, 512)          2048      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 25, 25, 512)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 512)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 25, 25, 512)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 25, 25, 128)          65536     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 25, 25, 128)          512       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 25, 25, 128)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 25, 25, 128)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 25, 25, 512)          65536     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 25, 25, 512)          2048      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 25, 25, 512)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 25, 25, 512)          4608      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 25, 25, 512)          2048      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 25, 25, 512)          0         ['block4d_bn[0][0]']
#  tion)
#  block4d_se_squeeze (Global  (None, 512)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multipl  (None, 25, 25, 512)          0         ['block4d_activation[0][0]',
#  y)                                                                  'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv  (None, 25, 25, 128)          65536     ['block4d_se_excite[0][0]']
#  2D)
#
#  block4d_project_bn (BatchN  (None, 25, 25, 128)          512       ['block4d_project_conv[0][0]']
#  ormalization)
#
#  block4d_drop (Dropout)      (None, 25, 25, 128)          0         ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)           (None, 25, 25, 128)          0         ['block4d_drop[0][0]',
#                                                                      'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2  (None, 25, 25, 512)          65536     ['block4d_add[0][0]']
#  D)
#
#  block4e_expand_bn (BatchNo  (None, 25, 25, 512)          2048      ['block4e_expand_conv[0][0]']
#  rmalization)
#
#  block4e_expand_activation   (None, 25, 25, 512)          0         ['block4e_expand_bn[0][0]']
#  (Activation)
#
#  block4e_dwconv2 (Depthwise  (None, 25, 25, 512)          4608      ['block4e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4e_bn (BatchNormaliza  (None, 25, 25, 512)          2048      ['block4e_dwconv2[0][0]']
#  tion)
#
#  block4e_activation (Activa  (None, 25, 25, 512)          0         ['block4e_bn[0][0]']
#  tion)
#
#  block4e_se_squeeze (Global  (None, 512)                  0         ['block4e_activation[0][0]']
#  AveragePooling2D)
#
#  block4e_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4e_se_squeeze[0][0]']
#  e)
#
#  block4e_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multipl  (None, 25, 25, 512)          0         ['block4e_activation[0][0]',
#  y)                                                                  'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv  (None, 25, 25, 128)          65536     ['block4e_se_excite[0][0]']
#  2D)
#
#  block4e_project_bn (BatchN  (None, 25, 25, 128)          512       ['block4e_project_conv[0][0]']
#  ormalization)
#
#  block4e_drop (Dropout)      (None, 25, 25, 128)          0         ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)           (None, 25, 25, 128)          0         ['block4e_drop[0][0]',
#                                                                      'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2  (None, 25, 25, 512)          65536     ['block4e_add[0][0]']
#  D)
#
#  block4f_expand_bn (BatchNo  (None, 25, 25, 512)          2048      ['block4f_expand_conv[0][0]']
#  rmalization)
#
#  block4f_expand_activation   (None, 25, 25, 512)          0         ['block4f_expand_bn[0][0]']
#  (Activation)
#
#  block4f_dwconv2 (Depthwise  (None, 25, 25, 512)          4608      ['block4f_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4f_bn (BatchNormaliza  (None, 25, 25, 512)          2048      ['block4f_dwconv2[0][0]']
#  tion)
#
#  block4f_activation (Activa  (None, 25, 25, 512)          0         ['block4f_bn[0][0]']
#  tion)
#
#  block4f_se_squeeze (Global  (None, 512)                  0         ['block4f_activation[0][0]']
#  AveragePooling2D)
#
#  block4f_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4f_se_squeeze[0][0]']
#  e)
#
#  block4f_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multipl  (None, 25, 25, 512)          0         ['block4f_activation[0][0]',
#  y)                                                                  'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv  (None, 25, 25, 128)          65536     ['block4f_se_excite[0][0]']
#  2D)
#
#  block4f_project_bn (BatchN  (None, 25, 25, 128)          512       ['block4f_project_conv[0][0]']
#  ormalization)
#
#  block4f_drop (Dropout)      (None, 25, 25, 128)          0         ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)           (None, 25, 25, 128)          0         ['block4f_drop[0][0]',
#                                                                      'block4e_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 25, 25, 768)          98304     ['block4f_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 25, 25, 768)          3072      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 25, 25, 768)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv2 (Depthwise  (None, 25, 25, 768)          6912      ['block5a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5a_bn (BatchNormaliza  (None, 25, 25, 768)          3072      ['block5a_dwconv2[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 25, 25, 768)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 768)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 768)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 32)             24608     ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 768)            25344     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 25, 25, 768)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 25, 25, 160)          122880    ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 25, 25, 160)          640       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 25, 25, 960)          153600    ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 25, 25, 960)          3840      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 25, 25, 960)          0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv2 (Depthwise  (None, 25, 25, 960)          8640      ['block5b_expand_activation[0]
#  Conv2D)                                                            [0]']
# ...
#  tion)
#
#  block6l_se_squeeze (Global  (None, 1536)                 0         ['block6l_activation[0][0]']
#  AveragePooling2D)
#
#  block6l_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6l_se_squeeze[0][0]']
#  e)
#
#  block6l_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6l_se_reshape[0][0]']
#
#  block6l_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6l_se_reduce[0][0]']
#
#  block6l_se_excite (Multipl  (None, 13, 13, 1536)         0         ['block6l_activation[0][0]',
#  y)                                                                  'block6l_se_expand[0][0]']
#
#  block6l_project_conv (Conv  (None, 13, 13, 256)          393216    ['block6l_se_excite[0][0]']
#  2D)
#
#  block6l_project_bn (BatchN  (None, 13, 13, 256)          1024      ['block6l_project_conv[0][0]']
#  ormalization)
#
#  block6l_drop (Dropout)      (None, 13, 13, 256)          0         ['block6l_project_bn[0][0]']
#
#  block6l_add (Add)           (None, 13, 13, 256)          0         ['block6l_drop[0][0]',
#                                                                      'block6k_add[0][0]']
#
#  block6m_expand_conv (Conv2  (None, 13, 13, 1536)         393216    ['block6l_add[0][0]']
#  D)
#
#  block6m_expand_bn (BatchNo  (None, 13, 13, 1536)         6144      ['block6m_expand_conv[0][0]']
#  rmalization)
#
#  block6m_expand_activation   (None, 13, 13, 1536)         0         ['block6m_expand_bn[0][0]']
#  (Activation)
#
#  block6m_dwconv2 (Depthwise  (None, 13, 13, 1536)         13824     ['block6m_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6m_bn (BatchNormaliza  (None, 13, 13, 1536)         6144      ['block6m_dwconv2[0][0]']
#  tion)
#
#  block6m_activation (Activa  (None, 13, 13, 1536)         0         ['block6m_bn[0][0]']
#  tion)
#
#  block6m_se_squeeze (Global  (None, 1536)                 0         ['block6m_activation[0][0]']
#  AveragePooling2D)
#
#  block6m_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6m_se_squeeze[0][0]']
#  e)
#
#  block6m_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6m_se_reshape[0][0]']
#
#  block6m_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6m_se_reduce[0][0]']
#
#  block6m_se_excite (Multipl  (None, 13, 13, 1536)         0         ['block6m_activation[0][0]',
#  y)                                                                  'block6m_se_expand[0][0]']
#
#  block6m_project_conv (Conv  (None, 13, 13, 256)          393216    ['block6m_se_excite[0][0]']
#  2D)
#
#  block6m_project_bn (BatchN  (None, 13, 13, 256)          1024      ['block6m_project_conv[0][0]']
#  ormalization)
#
#  block6m_drop (Dropout)      (None, 13, 13, 256)          0         ['block6m_project_bn[0][0]']
#
#  block6m_add (Add)           (None, 13, 13, 256)          0         ['block6m_drop[0][0]',
#                                                                      'block6l_add[0][0]']
#
#  block6n_expand_conv (Conv2  (None, 13, 13, 1536)         393216    ['block6m_add[0][0]']
#  D)
#
#  block6n_expand_bn (BatchNo  (None, 13, 13, 1536)         6144      ['block6n_expand_conv[0][0]']
#  rmalization)
#
#  block6n_expand_activation   (None, 13, 13, 1536)         0         ['block6n_expand_bn[0][0]']
#  (Activation)
#
#  block6n_dwconv2 (Depthwise  (None, 13, 13, 1536)         13824     ['block6n_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6n_bn (BatchNormaliza  (None, 13, 13, 1536)         6144      ['block6n_dwconv2[0][0]']
#  tion)
#
#  block6n_activation (Activa  (None, 13, 13, 1536)         0         ['block6n_bn[0][0]']
#  tion)
#
#  block6n_se_squeeze (Global  (None, 1536)                 0         ['block6n_activation[0][0]']
#  AveragePooling2D)
#
#  block6n_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6n_se_squeeze[0][0]']
#  e)
#
#  block6n_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6n_se_reshape[0][0]']
#
#  block6n_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6n_se_reduce[0][0]']
#
#  block6n_se_excite (Multipl  (None, 13, 13, 1536)         0         ['block6n_activation[0][0]',
#  y)                                                                  'block6n_se_expand[0][0]']
#
#  block6n_project_conv (Conv  (None, 13, 13, 256)          393216    ['block6n_se_excite[0][0]']
#  2D)
#
#  block6n_project_bn (BatchN  (None, 13, 13, 256)          1024      ['block6n_project_conv[0][0]']
#  ormalization)
#
#  block6n_drop (Dropout)      (None, 13, 13, 256)          0         ['block6n_project_bn[0][0]']
#
#  block6n_add (Add)           (None, 13, 13, 256)          0         ['block6n_drop[0][0]',
#                                                                      'block6m_add[0][0]']
#
#  block6o_expand_conv (Conv2  (None, 13, 13, 1536)         393216    ['block6n_add[0][0]']
#  D)
#
#  block6o_expand_bn (BatchNo  (None, 13, 13, 1536)         6144      ['block6o_expand_conv[0][0]']
#  rmalization)
#
#  block6o_expand_activation   (None, 13, 13, 1536)         0         ['block6o_expand_bn[0][0]']
#  (Activation)
#
#  block6o_dwconv2 (Depthwise  (None, 13, 13, 1536)         13824     ['block6o_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6o_bn (BatchNormaliza  (None, 13, 13, 1536)         6144      ['block6o_dwconv2[0][0]']
#  tion)
#  block6o_activation (Activa  (None, 13, 13, 1536)         0         ['block6o_bn[0][0]']
#  tion)
#
#  block6o_se_squeeze (Global  (None, 1536)                 0         ['block6o_activation[0][0]']
#  AveragePooling2D)
#
#  block6o_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6o_se_squeeze[0][0]']
#  e)
#
#  block6o_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6o_se_reshape[0][0]']
#
#  block6o_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6o_se_reduce[0][0]']
#
#  block6o_se_excite (Multipl  (None, 13, 13, 1536)         0         ['block6o_activation[0][0]',
#  y)                                                                  'block6o_se_expand[0][0]']
#
#  block6o_project_conv (Conv  (None, 13, 13, 256)          393216    ['block6o_se_excite[0][0]']
#  2D)
#
#  block6o_project_bn (BatchN  (None, 13, 13, 256)          1024      ['block6o_project_conv[0][0]']
#  ormalization)
#
#  block6o_drop (Dropout)      (None, 13, 13, 256)          0         ['block6o_project_bn[0][0]']
#
#  block6o_add (Add)           (None, 13, 13, 256)          0         ['block6o_drop[0][0]',
#                                                                      'block6n_add[0][0]']
#
#  top_conv (Conv2D)           (None, 13, 13, 1280)         327680    ['block6o_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 13, 13, 1280)         5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 13, 13, 1280)         0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 20331360 (77.56 MB)
# Trainable params: 20177488 (76.97 MB)
# Non-trainable params: 153872 (601.06 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense

# Freeze the base model
base_model.trainable = False

# Add a custom classification head
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(200, activation="softmax")
])

# Compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)

# Fit the data
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    batch_size=32,
    epochs=10,
    callbacks=[early_stopping]
)

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/10
# 99/99 [==============================] - 512s 5s/step - loss: 4.2643 - accuracy: 0.1522 - val_loss: 3.3736 - val_accuracy: 0.2875
# Epoch 2/10
# 99/99 [==============================] - 503s 5s/step - loss: 2.8437 - accuracy: 0.4051 - val_loss: 2.7132 - val_accuracy: 0.3944
# Epoch 3/10
# 99/99 [==============================] - 497s 5s/step - loss: 2.2352 - accuracy: 0.5264 - val_loss: 2.3617 - val_accuracy: 0.4631
# Epoch 4/10
# 99/99 [==============================] - 494s 5s/step - loss: 1.8440 - accuracy: 0.6140 - val_loss: 2.1730 - val_accuracy: 0.4771
# Epoch 5/10
# 99/99 [==============================] - 494s 5s/step - loss: 1.5759 - accuracy: 0.6761 - val_loss: 2.0058 - val_accuracy: 0.5280
# Epoch 6/10
# 99/99 [==============================] - 498s 5s/step - loss: 1.3824 - accuracy: 0.7232 - val_loss: 1.9043 - val_accuracy: 0.5433
# Epoch 7/10
# 99/99 [==============================] - 493s 5s/step - loss: 1.2245 - accuracy: 0.7583 - val_loss: 1.8333 - val_accuracy: 0.5471
# Epoch 8/10
# 99/99 [==============================] - 496s 5s/step - loss: 1.1130 - accuracy: 0.7895 - val_loss: 1.7566 - val_accuracy: 0.5725
# Epoch 9/10
# 99/99 [==============================] - 495s 5s/step - loss: 1.0164 - accuracy: 0.8073 - val_loss: 1.7226 - val_accuracy: 0.5814
# Epoch 10/10
# 99/99 [==============================] - 496s 5s/step - loss: 0.9257 - accuracy: 0.8318 - val_loss: 1.6666 - val_accuracy: 0.5903
# 25/25 [==============================] - 98s 4s/step - loss: 1.6666 - accuracy: 0.5903
# Test Loss: 1.6665704250335693, Test Accuracy: 0.5903307795524597

# %%
model.save("efficientnetv2_model.h5")
# Out:
# C:\Users\brake\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Unfreeze a few layers at a time
for layer in base_model.layers[-20:]:
    layer.trainable = True

# Recompile the model after unfreezing layers
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), 
              loss="categorical_crossentropy", 
              metrics=["accuracy"])

# Continue training
history_improved = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    batch_size=32,
    epochs=5,
    callbacks=[early_stopping]
)

# %%
test_df = pd.read_csv("test_images_path.csv")

test_images = []
# Iterate over rows in the DataFrame
for _, row in test_df.iterrows():
    # Read the image
    im_path = row['image_path']
    image = cv2.imread(f'test_images{im_path}')
    
    # Resize the image to 400x400
    image_resized = cv2.resize(image, (400, 400))
    
    # Append to the list of images and labels
    test_images.append(image_resized)


predictions = model.predict(np.array(test_images))
predicted_labels = np.argmax(predictions, axis = 1)

submission_df = pd.DataFrame({
    'id': test_df['id'],
    'label': predicted_labels + 1
})
submission_df.to_csv('submission.csv', index=False)
# Out:
# 125/125 [==============================] - 1094s 9s/step
